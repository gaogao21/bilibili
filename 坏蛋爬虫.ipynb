# %%
import requests
from bs4 import BeautifulSoup
import time

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
}

f= open ('D:/YY/doupo.txt','a+')

def get_info(url):
    res = requests.get(url,headers=headers)
    if res.status_code == 200:
        contents=re.findall('<p>(.*?)</p>',res.content.decode('utf-8'),re.S)
        for content in contents:
            f.write(content+'\n')
    else:
        pass

if __name__ == '__main__':
    urls = ['http://www.huaidan1.com/{}.html'.format(str(i)) for i in range(2,100)]
    for url in urls:
        get_info(url)
        time.sleep(1)
    f.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-264f7fdb5a4d> in <module>()
#      21     urls = ['http://www.huaidan1.com/{}.html'.format(str(i)) for i in range(2,100)]
#      22     for url in urls:
# ---> 23         get_info(url)
#      24         time.sleep(1)
#      25     f.close()
#
# <ipython-input-4-264f7fdb5a4d> in get_info(url)
#      12     res = requests.get(url,headers=headers)
#      13     if res.status_code == 200:
# ---> 14         contents=re.findall('<p>(.*?)</p>',res.content.decode('utf-8'),re.S)
#      15         for content in contents:
#      16             f.write(content+'\n')
#
# NameError: name 're' is not defined

# %%
import requests
from bs4 import BeautifulSoup
import time

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
}

info_lists=[]

def judgment_sex(class_name):
    if class_name == 'womenIcon':
        return '女'
    else :
        return '男'
    def get_info(url):
        res=resquests.get(url)
        ids=re.findall('<h2>(.*?)',res.text,re.S)
        levels=re.findall('<div class="articleGender \D+Icon">(.*?)</div>',res.text,re.S)
        sexs=re.findall('<div class="articleGender (.*?)">',res.text,re.S)
        contents=re.findall('div class="conten">.*?<span>(.*?)</span>',res.text,re.S)
        laughs=re.findall('<span class="stats-vote"><i class="number">(\d+)</i>',res.text,re.S)
        comments=re.findall('<i class="number">(\d+)</i> 评论',res.text,re.S)
        for id,level,sex,content,laugh,comment in zip(ids,levels,sexs,contents,laughs,comments):
            info = {
                'id':id,
                'level':level,
                'content':content,
                'laugh':laugh,
                'comment':comment
            }
            info_lists.append(info)
            
if __name__ == '__main__':
    urls = ['http://www.qiushibaike.com/text/page/{}/'.format(str(i)) for i in range(2,36)]
    for url in urls:
        get_info(url)
    for info_list in info_lists:
        f= open('D:/YY/qiushi.txt','a+')
        try:
               f.write(info_list['id'+'\n'])
               f.write(info_list['level'+'\n'])
               f.write(info_list['sex'+'\n'])
               f.write(info_list['content'+'\n'])
               f.write(info_list['laugh'+'\n'])
               f.write(info_list['comment'+'\n\n'])
               f.close()
        except UnicodeEncodeError:
                  pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c30bab4f77dd> in <module>()
#      35     urls = ['http://www.qiushibaike.com/text/page/{}/'.format(str(i)) for i in range(2,36)]
#      36     for url in urls:
# ---> 37         get_info(url)
#      38     for info_list in info_lists:
#      39         f= open('D:/YY/qiushi.txt','a+')
#
# <ipython-input-4-264f7fdb5a4d> in get_info(url)
#      12     res = requests.get(url,headers=headers)
#      13     if res.status_code == 200:
# ---> 14         contents=re.findall('<p>(.*?)</p>',res.content.decode('utf-8'),re.S)
#      15         for content in contents:
#      16             f.write(content+'\n')
#
# NameError: name 're' is not defined

# %%
import requests
import re

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36'
}

info_lists = []

def judgment_sex(class_name):
  if class_name == 'womenIcon':
      return '女'
  else:
      return  '男'

def get_info(url):
    res = requests.get(url)
    ids = re.findall('<h2>(.*?)</h2>',res.text,re.S)
    levels = re.findall('<div class="articleGender \D+Icon">(.*?)</div>',res.text,re.S)
    sexs = re.findall('<div class="articleGender (.*?)">',res.text,re.S)
    contents = re.findall('<div class="content">.*?<span>(.*?)</span>',res.text,re.S)
    laughs = re.findall('<span class="stats-vote"><i class="number">(\d+)</i>',res.text,re.S)
    comments = re.findall('<i class="number">(\d+)</i> 评论',res.text,re.S)
    for id,level,sex,content,laugh,comment in zip(ids,levels,sexs,contents,laughs,comments):
        info = {
            'id':id,
            'level':level,
            'sex':judgment_sex(sex),
            'content':content,
            'laugh':laugh,
            'comment':comment
        }
        info_lists.append(info)

if __name__ == '__main__':
    urls = ['http://www.qiushibaike.com/text/page/{}/'.format(str(i)) for i in range(1,36)]
    for url in urls:
        get_info(url)
    for info_list in info_lists:
        # f = open('C:/Users/Administrator//Desktop/qiushi.text','a+')
        # try:
        #     f.write(info_list['id']+'\n')
        #     f.write(info_list['level'] + '\n')
        #     f.write(info_list['sex'] + '\n')
        #     f.write(info_list['content'] + '\n')
        #     f.write(info_list['laugh'] + '\n')
        #     f.write(info_list['comment'] + '\n\n')
        #     f.close()
        # except UnicodeEncodeError:
        #     pass
        print(info_list)
# Out:
# {'id': '\n世间安得双全法，\n', 'level': '27', 'sex': '男', 'content': '\n\n\n记得刚参加工作那段时间，住在单位里的单身公寓，就是俗称的筒子楼。每人一间房，大概十几个平米，关上门来就算是一户居民，所用的盥洗间是公用的，一幢楼有五层大概住几十户，大多都是本单位的人。平时门一开就可以互相串门了。一楼有食堂，每天晚上食堂五点准时开饭。那天，单位有事，下班稍微有点晚，没赶上饭点。于是就心血来潮，买菜准备自己做。很清楚的记得，当时买了鸡蛋、西红柿、河虾和韭菜。<br/>回去后把菜清洗好。准备大展身手了。<br/>当时正在做西红柿炒鸡蛋，西红柿已切好，打鸡蛋的时候由于劲用大了一点，于是细碎\n…\n', 'laugh': '631', 'comment': '7'}
# {'id': '\n道士下山会女神\n', 'level': '99', 'sex': '男', 'content': '\n\n\n侄子高考结束，兴奋得要上天，在网上随便对了一下答案，属于正常发挥。<br/>我哥提醒他：在正式成绩出来前，别人问起，别太张扬要低调点哈。<br/>侄子满口答应：我最多往上加一百多分凑够五百分，不算张扬吧？\n\n', 'laugh': '1314', 'comment': '16'}
# {'id': '\n荆轲刺秦王100\n', 'level': '20', 'sex': '男', 'content': '\n\n\n下班回来，路边算命的大爷拦住我。“你是单身吧！”“大师你算的真准，这个要怎么破。”说着我掏出50块…你多大了？…我二十七。…你到二十八在来问我。为什么啊，这样吉利。\n\n', 'laugh': '1334', 'comment': '0'}
# {'id': '\n清风拂杨柳。？\n', 'level': '26', 'sex': '男', 'content': '\n\n\n小生不才，没有故事，没有女朋友，没有考研，没有不治之症，也不放羊，哪条腿都没断，不养乌龟不养狗，不骑猪上战场，KTV里也唱不哭小姐，也不是从那那过来的，一个平凡到极致的单身狗！老子就是单纯来骗赞的！ 就要20个，就是这么狂，而且这条评论还是复制的！\n\n', 'laugh': '1132', 'comment': '17'}
# ...

# %%
import requests
import re
import time

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
}

f = open('D:/YY/qiushi.txt','a+')

def get_info(url):
    res = requests.get(url,headers=headers)
    if res.status_code == 200:
        contents = re.findall('<p>(.*?)</p>',res.content.decode('utf-8'),re.S)
        for content in contents:
            f.write(content+'\n')
    else:
        pass

if __name__ == '__main__':
    urls = ['http://www.huaidan1.com/{}.html'.format(str(i)) for i in range(2,100)]
    for url in urls:
        get_info(url)
        time.sleep(1)
    f.close()

# %%
import requests
from lxml import etree

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
}
res=requests.get('https://book.douban.com/top250',headers=headers)
html=etree.HTML(res.text)
result=etree.tostring(html)
print(result)
# Out:
# b'<html lang="zh-cmn-Hans" class="ua-windows ua-webkit book-new-nav">\n<head>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n  <title>&#35910;&#29923;&#22270;&#20070; Top 250</title>\n  \n<script>!function(e){var o=function(o,n,t){var c,i,r=new Date;n=n||30,t=t||"/",r.setTime(r.getTime()+24*n*60*60*1e3),c="; expires="+r.toGMTString();for(i in o)e.cookie=i+"="+o[i]+c+"; path="+t},n=function(o){var n,t,c,i=o+"=",r=e.cookie.split(";");for(t=0,c=r.length;t&lt;c;t++)if(n=r[t].replace(/^\\s+|\\s+$/g,""),0==n.indexOf(i))return n.substring(i.length,n.length).replace(/\\"/g,"");return null},t=e.write,c={"douban.com":1,"douban.fm":1,"google.com":1,"google.cn":1,"googleapis.com":1,"gmaptiles.co.kr":1,"gstatic.com":1,"gstatic.cn":1,"google-analytics.com":1,"googleadservices.com":1},i=function(e,o){var n=new Image;n.onload=function(){},n.src="https://www.douban.com/j/except_report?kind=ra022&amp;reason="+encodeURIComponent(e)+"&amp;environment="+encodeURIComponent(o)},r=
# ...
